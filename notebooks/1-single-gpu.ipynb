# %% [markdown]
# # Scenario 1: Single-GPU Training
#
# | | |
# |---|---|
# | **Workload class** | Single-node, single-GPU training |
# | **Matrix status** | Ready |
# | **Shape** | 1 node, 1 GPU, 200 steps |
#
# **What this tests:** The most basic training job - one GPU, one node. This is the throughput baseline that scenarios 2 and 3 compare against for scaling efficiency.
#
# **Success criteria:**
# - Job completes within timeout
# - Throughput (samples/s) is recorded
# - GPU utilization > 0% during training
#
# **Slurm equivalent:** `sbatch` with a single GPU. Trainer v2 + Kueue handle it the same way - submit, schedule, run, collect metrics.
#
# ---
#
# *Counted runs: use Restart Kernel & Run All.*

# %%
# !uv run bench run single-gpu --repetitions 1

# %%
# !uv run bench report
