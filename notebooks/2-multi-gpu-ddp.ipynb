# %% [markdown]
# # Scenario 2: Multi-GPU DDP (Single Node)
#
# | | |
# |---|---|
# | **Workload class** | Single-node, multi-GPU (DDP) |
# | **Matrix status** | Ready |
# | **Shape** | 1 node, 4 GPUs, 200 steps |
#
# **What this tests:** PyTorch DDP across 4 GPUs on one node. The runtime launches 4 workers and PyTorch synchronizes gradients over NVLink/PCIe.
#
# **Success criteria:**
# - `world_size=4` in logs (all GPUs participated)
# - Throughput higher than scenario 1. The ratio gives scaling efficiency.
#
# **Slurm equivalent:** `srun --gpus-per-node=4`. Trainer v2 auto-injects `WORLD_SIZE`, `RANK`, and `MASTER_ADDR` - no manual configuration.
#
# ---
#
# *Counted runs: use Restart Kernel & Run All.*

# %%
# !uv run bench run multi-gpu-ddp --repetitions 1

# %%
# !uv run bench report
